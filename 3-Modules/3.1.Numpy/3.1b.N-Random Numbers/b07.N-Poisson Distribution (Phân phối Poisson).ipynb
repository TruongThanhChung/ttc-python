# %% [markdown]
# Poisson Distribution
# Poisson Distribution is a Discrete Distribution.
#
# It estimates how many times an event can happen in a specified time. e.g. If someone eats twice a day what is the probability he will eat thric?
#
# It has two parameers:
#
# lam -rate or known number of occurrences e.g. 2 for above poblem.
#
# size - The shape of the return
# Phân phối Poisson
# Phân phối Poisson là một phân phối rời rạc .
#
# Nó ước tính số lần một sự kiện có thể xảy ra trong một thời gian nhất định. ví dụ: Nếu ai đó ăn hai lần một ngày thì xác suất anh ta sẽ ăn ba lần là bao nhiê?
#
# Nó có hai thamsố:
#
# lam- tỷ lệ hoặc số lần xuất hiện đã biết, ví dụ 2 cho vấn đềtrên.
#
# size- Hình dạng của mảng trả về.ed array.

# %%
# Generate a random 1x10 distribution for occurrence 2:
# Tạo phân phối 1x10 ngẫu nhiên cho lần xuất hiện 2:
from numpy import random

x = random.poisson(lam=2, size=10)

print(x)
# Out:
# [0 1 4 4 3 2 3 0 1 0]

# %% [markdown]
# Visualization of Poisson Distribution
# Trực quan hóa phân phối Poisson

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.poisson(lam=2, size=1000), kde=False)

plt.show()
# Out:
# C:\Users\MrMoc\AppData\Local\Temp\ipykernel_10216\1134702419.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=2, size=1000), kde=False)

# %% [markdown]
# Difference Between Normal and Poisson Distribution
# Normal distribution is continuous whereas poisson is discrete.
#
# But we can see that similar to binomial for a large enough poisson distribution it will become similar to normal distribution with certain std dev and me
# Sự khác biệt giữa phân phối bình thường và phân phối Poisson
# Phân phối chuẩn là liên tục trong khi poisson là rời rạc.
#
# Nhưng chúng ta có thể thấy rằng tương tự như phân phối nhị thức đối với một phân phối poisson đủ lớn, nó sẽ trở nên tương tự như phân phối chuẩn với độ phát triển và giá trị trung bình nhất định.an.

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
sns.distplot(random.poisson(lam=50, size=1000), hist=False, label='poisson')

plt.show()
# Out:
# C:\Users\MrMoc\AppData\Local\Temp\ipykernel_10216\546134220.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\MrMoc\AppData\Local\Temp\ipykernel_10216\546134220.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %% [markdown]
# Difference Between Binomial and Poisson Distribution
# Binomial distribution only has two possible outcomes, whereas poisson distribution can have unlimited possible outcomes.
#
# But for very large n and near-zero p binomial distribution is near identical to poisson distribution such that n * p is nearly equal to l
# Sự khác biệt giữa phân phối nhị thức và phân phối Poisson
# Phân phối nhị thức chỉ có hai kết quả có thể xảy ra, trong khi phân phối poisson có thể có kết quả không giới hạn.
#
# Nhưng đối với phân phối nhị thức rất lớ n nvà gần b-ng  0 pthì gần giống với phân phối poisson sao cho n  * pgần bằng lam.am.

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.binomial(n=1000, p=0.01, size=1000), hist=False, label='binomial')
sns.distplot(random.poisson(lam=10, size=1000), hist=False, label='poisson')

plt.show()
# Out:
# C:\Users\MrMoc\AppData\Local\Temp\ipykernel_10216\2335209617.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=1000, p=0.01, size=1000), hist=False, label='binomial')
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\MrMoc\AppData\Local\Temp\ipykernel_10216\2335209617.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...
