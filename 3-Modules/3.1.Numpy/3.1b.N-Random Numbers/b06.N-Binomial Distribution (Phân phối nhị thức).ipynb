# %% [markdown]
# Binomial Distribution
# Binomial Distribution is a Discrete Distribution.
#
# It describes the outcome of binary scenarios, e.g. toss of a coin, it will either be head or tail.
#
# It has three parametrs:
#
# n - number of tials.
#
# p - probability of occurence of each trial (e.g. for toss of a coin 0. each).
#
# size - The shape of the retu
# Phân phối nhị thức
# Phân phối nhị thức là một phân phối rời rạc .
#
# Nó mô tả kết quả của các kịch bản nhị phân, ví dụ như tung đồng xu, nó sẽ là đầu hoặc đuô.
#
# Nó có ba thamsố:
#
# n- số lượng thử nhiệm.
#
# p- xác suất xảy ra của mỗi lần thử (ví dụ: tung đồng xu 05 lần).
#
# size- Hình dạng của mảng trả về.rned array.

# %% [markdown]
# Discrete Distribution:The distribution is defined at separate set of events, e.g. a coin toss's result is discrete as it can be only head or tails whereas height of people is continuous as it can be 170, 170.1, 170.11 and so on.
# Phân phối rời rạc: Phân phối được xác định theo tập hợp các sự kiện riêng biệt, ví dụ: kết quả của việc tung đồng xu là rời rạc vì nó có thể chỉ là đầu hoặc đuôi trong khi chiều cao của mọi người là liên tục vì nó có thể là 170, 170,1, 170,11, v.v.

# %%
# Given 10 trials for coin toss generate 10 data points:
# Đưa ra 10 lần thử tung đồng xu sẽ tạo ra 10 điểm dữ liệu:
from numpy import random

x = random.binomial(n=10, p=0.5, size=10)

print(x)
# Out:
# [3 3 5 2 4 4 3 6 6 4]

# %% [markdown]
# Visualization of Binomial Distribution
# Trực quan hóa phân phối nhị thức

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

plt.show()
# Out:
# C:\Users\MrMoc\AppData\Local\Temp\ipykernel_12944\1627534489.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

# %% [markdown]
# Difference Between Normal and Binomial Distribution
# The main difference is that normal distribution is continous whereas binomial is discrete, but if there are enough data points it will be quite similar to normal distribution with certain loc and scale
# Sự khác biệt giữa phân phối chuẩn và phân phối nhị thức
# Sự khác biệt chính là phân phối chuẩn là liên tục trong khi phân phối nhị thức là rời rạc, nhưng nếu có đủ điểm dữ liệu thì nó sẽ khá giống với phân phối chuẩn với vị trí và tỷ lệ nhất định..

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')

plt.show()
# Out:
# C:\Users\MrMoc\AppData\Local\Temp\ipykernel_12944\3842674151.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\MrMoc\AppData\Local\Temp\ipykernel_12944\3842674151.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
