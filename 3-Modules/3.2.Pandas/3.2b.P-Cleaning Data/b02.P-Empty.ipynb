# %% [markdown]
# Empty Cells
# Empty cells can potentially give you a wrong result when you analyze data
# Ô trống
# Các ô trống có thể cho bạn kết quả sai khi phân tích dữ liệu..

# %% [markdown]
# Remove Rows
# One way to deal with empty cells is to remove rows that contain empty cells.
#
# This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the resu
# Xóa hàng
# Một cách để xử lý các ô trống là loại bỏ các hàng chứa ô trống.
#
# Điều này thường là bình thường vì các tập dữ liệu có thể rất lớn và việc loại bỏ một vài hàng sẽ không ảnh hưởng lớn đến kết quả.lt.

# %%
# Return a new Data Frame with no empty cells:
# Trả về Khung dữ liệu mới không có ô trống:
import pandas as pd

df = pd.read_csv('C:/Users/thanh/data.csv')

new_df = df.dropna()

print(new_df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %% [markdown]
# Note: By default, the dropna() method returns a new DataFrame, and will not change the original.
# Lưu ý: Theo mặc định, phương dropna()thức trả về DataFrame mới và sẽ không thay đổi bản gốc.

# %%
If you want to change the original DataFrame, use the inplace = True argument:
Nếu bạn muốn thay đổi DataFrame gốc, hãy sử dụng inplace = Trueđối số:

# %%
# Remove all rows with NULL values:
# Xóa tất cả các hàng có giá trị NULL:
import pandas as pd

df = pd.read_csv('C:/Users/thanh/data.csv')

df.dropna(inplace = True)

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %% [markdown]
# Note: Now, the dropna(inplace = True) will NOT return a new DataFrame, but it will remove all rows containing NULL values from the original DataFrame.
# Lưu ý: Theo mặc định, phương thức dropna() trả về DataFrame mới và sẽ không thay đổi bản gốc.

# %% [markdown]
# Replace Empty Values
# Another way of dealing with empty cells is to insert a new value instead.
#
# This way you do not have to delete entire rows just because of some empty cell.
#
# The fillna() method allows us to replace empty cells with a v
# Thay thế các giá trị trống
# Một cách khác để xử lý các ô trống là chèn một giá trị mới thay thế.
#
# Bằng cách này bạn không phải xóa toàn bộ hàng chỉ vì một số ô trốn.
#
# Phương thức này fil lna()cho phép chúng ta thay thế các ô trống bằng một giá trị:alue:

# %%
# Replace NULL values with the number 130:
# Thay thế giá trị NULL bằng số 130:
import pandas as pd

df = pd.read_csv('C:/Users/thanh/data.csv')

df.fillna(130, inplace = True)

# %% [markdown]
# Replace Only For Specified Columns
# The example above replaces all empty cells in the whole Data Frame.
#
# To only replace empty values for one column, specify the column name for the DataFra
# Chỉ thay thế cho các cột được chỉ định
# Ví dụ trên thay thế tất cả các ô trống trong toàn bộ Data Frame.
#
# Để chỉ thay thế các giá trị trống cho một cột, hãy chỉ định tên cột cho DataFrame:me:

# %%
# Replace NULL values in the "Calories" columns with the number 130:
# Thay thế giá trị NULL trong cột "Calo" bằng số 130:
import pandas as pd

df = pd.read_csv('C:/Users/thanh/data.csv')

df["Calories"].fillna(130, inplace = True)

# %% [markdown]
# Replace Using Mean, Median, or Mode
# A common way to replace empty cells, is to calculate the mean, median or mode value of the column.
#
# Pandas uses the mean() median() and mode() methods to calculate the respective values for a specified colu
# Thay thế bằng cách sử dụng giá trị trung bình, trung vị hoặc chế độ
# Một cách phổ biến để thay thế các ô trống là tính giá trị trung bình, trung vị hoặc chế độ của cột.
#
# Pandas sử dụng các phương thức mean() median()và mode()để tính toán các giá trị tương ứng cho một cột được chỉ định:mn:

# %%
# Calculate the MEAN, and replace any empty values with it:
# Tính MEAN và thay thế bất kỳ giá trị trống nào bằng nó:
import pandas as pd

df = pd.read_csv('C:/Users/thanh/data.csv')

x = df["Calories"].mean()

df["Calories"].fillna(x, inplace = True)

# %% [markdown]
# Mean = the average value (the sum of all values divided by number of values).
# Giá trị trung bình = giá trị trung bình (tổng của tất cả các giá trị chia cho số lượng giá trị).

# %%
# Calculate the MEDIAN, and replace any empty values with it:
# Tính toán MEDIAN và thay thế bất kỳ giá trị trống nào bằng nó:
import pandas as pd

df = pd.read_csv('C:/Users/thanh/data.csv')

x = df["Calories"].median()

df["Calories"].fillna(x, inplace = True)

# %% [markdown]
# Median = the value in the middle, after you have sorted all values ascending.
# Trung vị = giá trị ở giữa, sau khi bạn đã sắp xếp tất cả các giá trị tăng dần.

# %%
# Calculate the MODE, and replace any empty values with it:
# Tính MODE và thay thế mọi giá trị trống bằng nó:
import pandas as pd

df = pd.read_csv('C:/Users/thanh/data.csv')

x = df["Calories"].mode()[0]

df["Calories"].fillna(x, inplace = True)

# %% [markdown]
# Mode = the value that appears most frequently.
# Chế độ = giá trị xuất hiện thường xuyên nhất.
